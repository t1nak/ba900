# %% [markdown]
# # Make bubble graph

# %%
import pandas as pd
df = pd.read_csv('2018_dec_overview.csv')
df['name'].unique()
import sys
sys.path.append("../../") 
 
from ba900 import assets_to_weights   

transform=assets_to_weights.tranformer()

from_=['ABSA BANK LTD ','THE STANDARD BANK OF S A LTD ','FIRSTRAND BANK LIMITED ','NEDBANK LTD ','INVESTEC BANK LTD ',\
      'CITIBANK N.A ','CAPITEC BANK ' , 'AFRICAN BANK LIMITED ','JPMORGAN CHASE BANK             ',\
       'THE HONGKONG AND SHANGHAI BANKING CORPORATION LIMITED - JOHANNESBURG BRANCH ',
       'STANDARD CHARTERED BANK ',\
       'CHINA CONSTRUCTION BANK         CORPORATION - JHB BRANCH ',
       'BANK OF CHINA LTD JHB BRANCH    ',
       'MERCANTILE BANK LTD ',
       'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
       'BNP PARIBAS SOUTH AFRICA BRANCH ',
       'SASFIN BANK LTD ',
       'BIDVEST BANK LIMITED ', 'DEUTSCHE BANK AG ',
       'STATE BANK OF INDIA '
      ]

to_=['ABSA', 'SBSA', 'FNB','NEDBANK', 'INVESTEC',\
    'CITYBANK','CAPITEC','AfricanB','JPM',\
     'HSBC','CHARTERED','ChinaConstruction',
   'BANK OF CHINA LTD JHB BRANCH    ',
    'MERCANTILE BANK LTD ',
   'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
   'BNP PARIBAS SOUTH AFRICA BRANCH ',
     'SASFIN BANK LTD ',
   'BIDVEST BANK LIMITED ', 'DEUTSCHE BANK AG ',
    'STATE BANK OF INDIA '
    ]
 
dictionary = dict(zip(from_, to_))

df['name'] = df['name'].map(dictionary)
old_names = [ 'total_assets', 'leverage', 'name']
new_names = [ 'Total_assets', 'Leverage', 'Name']
df.rename(columns=dict(zip(old_names, new_names)), inplace=True)
df['market_share_assets'] = df['Total_assets'].transform(lambda x: x / x.sum())



import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
 
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

 
# create data
df = df[np.isfinite(df['Total_assets'])]


x = df["Total_assets"].values
y = df["market_share_assets"].values
z = df["Leverage"].values

SBSA = df.loc[df["Name"]== 'SBSA']["Total_assets"] 
ABSA = df.loc[df["Name"]== 'ABSA']["Total_assets"]
NEDBANK = df.loc[df["Name"]== 'NEDBANK']["Total_assets"]
FNB = df.loc[df["Name"]== 'FNB']["Total_assets"]

Investec = df.loc[df["Name"]== 'INVESTEC']["Total_assets"]
 
SBSA_lev = df.loc[df["Name"]== 'SBSA']["Leverage"] 
ABSA_lev = df.loc[df["Name"]== 'ABSA']["Leverage"]
NEDBANK_lev = df.loc[df["Name"]== 'NEDBANK']["Leverage"]
FNB_lev = df.loc[df["Name"]== 'FNB']["Leverage"]
Investec_lev = df.loc[df["Name"]== 'INVESTEC']["Leverage"]

df = df[np.isfinite(df['Total_assets'])]

# Change color with c and alpha. I map the color to the X axis value.
plt.scatter(x, z, s=y*10000, c=z, cmap="ocean_r", linewidth=2)

#ns.distplot(x)
#sns.jointplot(x=x, y=z, kind="kde", space=0, color="blue", data=df)
#sns.jointplot(x=y, y=x, data=df,  marginal_kws=dict(bins=15, rug=True),annot_kws=dict(stat="r"),s=40, edgecolor="w", linewidth=1)
 
#
#Add titles (main and on axis)
plt.xlabel("Total assets in ZAR, Dec 2018")
plt.ylabel("Leverage")
plt.xlim([-200,1.55*10E11])
plt.ylim([0,15])

# plt.annotate('SBSA', xy=(SBSA, SBSA_lev), xytext=(1.18*10E11, SBSA_lev), color="white")
# plt.annotate('ABSA', xy=(ABSA, ABSA_lev), xytext=(0.88061*10E11, ABSA_lev), color="white")
# plt.annotate('NEDBANK', xy=(NEDBANK, NEDBANK_lev), xytext=(0.75061*10E11, NEDBANK_lev), color="white", size=6)
# plt.annotate('FNB', xy=(FNB, FNB_lev), xytext=(0.96*10E11, FNB_lev), color="white")
# plt.annotate('Investec', xy=(Investec, Investec_lev), xytext=(0.4*10E11, Investec_lev+1), color="black")
# Out:
# (0, 15)

# %% [markdown]
# # make bubble 2020

# %%
 
import pandas as pd

import sys
sys.path.append("../../") 
 
from ba900 import assets_to_weights   

transform=assets_to_weights.tranformer()

df = pd.read_csv('2020_02_overview_bank_data.csv')
df['name'].unique()


from_=['ABSA BANK LTD ','THE STANDARD BANK OF S A LTD ','FIRSTRAND BANK LIMITED ','NEDBANK LTD ','INVESTEC BANK LTD ',\
      'CITIBANK N.A ','CAPITEC BANK ' , 'AFRICAN BANK LIMITED ','JPMORGAN CHASE BANK             ',\
       'THE HONGKONG AND SHANGHAI BANKING CORPORATION LIMITED - JOHANNESBURG BRANCH ',
       'STANDARD CHARTERED BANK ',\
       'CHINA CONSTRUCTION BANK         CORPORATION - JHB BRANCH ',
       'BANK OF CHINA LTD JHB BRANCH    ',
       'MERCANTILE BANK LTD ', 'GRINDROD BANK LTD ',
       'BNP PARIBAS SOUTH AFRICA BRANCH ', 'AFRICAN BANK LIMITED ',
       'BIDVEST BANK LIMITED ', 'ALBARAKA BANK LTD ',
        'HBZ BANK LTD ',
       'SASFIN BANK LTD ', 'UBANK LIMITED ', 'DEUTSCHE BANK AG ',
       'GROBANK LTD ', 'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
       'DISCOVERY BANK LIMITED ', 'GBS MUTUAL BANK '
       
      ]

to_=['ABSA', 'SBSA', 'FNB','NEDBANK', 'INVESTEC',\
    'CITYBANK','CAPITEC','AfricanB','JPM',\
     'HSBC','CHARTERED','ChinaConstruction',
   'BANK OF CHINA LTD JHB BRANCH    ',
   'MERCANTILE BANK LTD ', 'GRINDROD BANK LTD ',
   'BNP PARIBAS SOUTH AFRICA BRANCH ', 'AFRICAN BANK LIMITED ',
   'BIDVEST BANK LIMITED ', 'ALBARAKA BANK LTD ',
    'HBZ BANK LTD ',
   'SASFIN BANK LTD ', 'UBANK LIMITED ', 'DEUTSCHE BANK AG ',
   'GROBANK LTD ', 'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
   'DISCOVERY BANK LIMITED ', 'GBS MUTUAL BANK '

    ]
 
dictionary = dict(zip(from_, to_))

df['name'] = df['name'].map(dictionary)
df
# Out:
#           time          debt        equity id   leverage  \
# 0   2020-02-01  1.345225e+12  1.045780e+11  A  12.863370
# 1   2020-02-01  1.154756e+12  9.421242e+10  B  12.256937
# 2   2020-02-01  1.116094e+12  9.022627e+10  C  12.369949
# 3   2020-02-01  9.869976e+11  7.458001e+10  D  13.234077
# 4   2020-02-01  4.418731e+11  3.724995e+10  E  11.862381
# 5   2020-02-01  9.820924e+10  2.499274e+10  F   3.929511
# 6   2020-02-01  6.089559e+10  9.392883e+09  G   6.483164
# 7   2020-02-01  5.836834e+10  5.623145e+09  H  10.380017
# 8   2020-02-01  3.112282e+10  4.658688e+09  I   6.680598
# 9   2020-02-01  4.494413e+10  8.634546e+09  J   5.205153
# 10  2020-02-01  3.727804e+10  5.039785e+09  K   7.396751
# 11  2020-02-01  1.266408e+10  2.608816e+09  L   4.854340
# 12  2020-02-01  1.124094e+10  1.581035e+09  M   7.109858
# 13  2020-02-01  1.713082e+10  4.399320e+09  N   3.893971
# 14  2020-02-01  1.884619e+10  8.369093e+09  O   2.251880
# ...

# %%
# Out:
# Text(4.79123e+11,12.8624,'E')

# %% [markdown]
# # Make bubble 2015

# %%
df = pd.read_csv('/Users/admin/git_repos/ba900/data/bubbles/2015_12_overview_bank_data.csv')
df['name'].unique()
# Out:
# array(['THE STANDARD BANK OF S A LTD ', 'ABSA BANK LTD ',
#        'FIRSTRAND BANK LIMITED ', 'NEDBANK LTD ', 'INVESTEC BANK LTD ',
#        'CAPITEC BANK ', 'CITIBANK N.A ',
#        'THE HONGKONG AND SHANGHAI BANKING CORPORATION LIMITED - JOHANNESBURG BRANCH ',
#        'STANDARD CHARTERED BANK ', 'AFRICAN BANK LIMITED ',
#        'CHINA CONSTRUCTION BANK         CORPORATION - JHB BRANCH ',
#        'BANK OF CHINA LTD JHB BRANCH    ', 'GRINDROD BANK LTD ',
#        'SOCIETE GENERALE JOHANNESBURG   BRANCH ', 'MERCANTILE BANK LTD ',
#        'JPMORGAN CHASE BANK             ', 'DEUTSCHE BANK AG ',
#        'ALBARAKA BANK LTD ', 'UBANK LIMITED ', 'HBZ BANK LTD ',
#        'SASFIN BANK LTD ', 'BNP PARIBAS SA ', 'BIDVEST BANK LIMITED ',
#        'BANK OF BARODA ', 'STATE BANK OF INDIA ',
#        'THE S A BANK OF ATHENS LTD '], dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

###############
###############
##### 2025!!! #####
####################

df = pd.read_csv('/Users/admin/git_repos/ba900/data/bubbles/2015_12_overview_bank_data.csv')
df['name'].unique()


from_=['ABSA BANK LTD ',
       'THE STANDARD BANK OF S A LTD ',
       'FIRSTRAND BANK LIMITED ',
       'NEDBANK LTD ',
       'INVESTEC BANK LTD ',\
        'CITIBANK N.A ',
       'CAPITEC BANK ' ,
        'AFRICAN BANK LIMITED ',    
       'JPMORGAN CHASE BANK             ',\
        'THE HONGKONG AND SHANGHAI BANKING CORPORATION LIMITED - JOHANNESBURG BRANCH ',
        'STANDARD CHARTERED BANK ', 
       'CHINA CONSTRUCTION BANK         CORPORATION - JHB BRANCH ',
       
       'BANK OF CHINA LTD JHB BRANCH    ', 
       'GRINDROD BANK LTD ',
       'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
       'MERCANTILE BANK LTD ',
       'DEUTSCHE BANK AG ',
       'ALBARAKA BANK LTD ', 
       'UBANK LIMITED ', 
       'HBZ BANK LTD ',
       'SASFIN BANK LTD ',
       'BNP PARIBAS SA ', 
       'BIDVEST BANK LIMITED ',
       'BANK OF BARODA ', 
       'STATE BANK OF INDIA ',
       'THE S A BANK OF ATHENS LTD '
      ]

to_=['ABSA', 
     'SBSA', 
     'FNB',
     'NEDBANK', 
     'INVESTEC',\
    'CITYBANK',
     'CAPITEC',
     'AfricanB',
     'JPM',\
     'HSBC',
     'CHARTERED','ChinaConstruction',
     'BANKofCHINA', 
    'GRINDROD BANK LTD ',
       'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
       'MERCANTILE BANK LTD ',
       'DEUTSCHE BANK AG ',
       'ALBARAKA BANK LTD ', 
       'UBANK LIMITED ', 
       'HBZ BANK LTD ',
       'SASFIN BANK LTD ',
       'BNP PARIBAS SA ', 
       'BIDVEST BANK LIMITED ',
       'BANK OF BARODA ', 
       'STATE BANK OF INDIA ',
       'THE S A BANK OF ATHENS LTD '   
    ]
 
dictionary = dict(zip(from_, to_))

df['name'] = df['name'].map(dictionary)
old_names = [ 'total_assets', 'leverage', 'name']
new_names = [ 'Total_assets', 'Leverage', 'Name']
df.rename(columns=dict(zip(old_names, new_names)), inplace=True)
df['market_share_assets'] = df['Total_assets'].transform(lambda x: x / x.sum())

# create data
df = df[np.isfinite(df['Total_assets'])]
x = df["Total_assets"].values
y = df["market_share_assets"].values
z = df["Leverage"].values

SBSA = df.loc[df["Name"]== 'SBSA']["Total_assets"] 
ABSA = df.loc[df["Name"]== 'ABSA']["Total_assets"]
NEDBANK = df.loc[df["Name"]== 'NEDBANK']["Total_assets"]
FNB = df.loc[df["Name"]== 'FNB']["Total_assets"]

Investec = df.loc[df["Name"]== 'INVESTEC']["Total_assets"]
 
SBSA_lev = df.loc[df["Name"]== 'SBSA']["Leverage"] 
ABSA_lev = df.loc[df["Name"]== 'ABSA']["Leverage"]
NEDBANK_lev = df.loc[df["Name"]== 'NEDBANK']["Leverage"]
FNB_lev = df.loc[df["Name"]== 'FNB']["Leverage"]
Investec_lev = df.loc[df["Name"]== 'INVESTEC']["Leverage"]

df = df[np.isfinite(df['Total_assets'])]


fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')

# Change color with c and alpha. I map the color to the X axis value.
ax1.scatter(x, z, s=y*10000, c=z, cmap="ocean_r", linewidth=2)
#Add titles (main and on axis)
ax1.xlabel("Total assets in ZAR, Dec 2015")
ax1.ylabel("Leverage")
ax1.xlim([-200,1.35*10E11])
ax1.annotate('A', xy=(SBSA, SBSA_lev), xytext=(1.18*10E11, SBSA_lev), color="white")
ax1.annotate('C', xy=(ABSA, ABSA_lev), xytext=(0.88061*10E11, ABSA_lev), color="white")
ax1.annotate('D', xy=(NEDBANK, NEDBANK_lev), xytext=(0.75061*10E11, NEDBANK_lev), color="white") # size=6
ax1.annotate('B', xy=(FNB, FNB_lev), xytext=(0.96*10E11, FNB_lev), color="white")
ax1.annotate('E', xy=(Investec, Investec_lev), xytext=(0.4*10E11, Investec_lev+1), color="black")

###############
###############
##### 2020!!! #####
####################
df = pd.read_csv('2020_02_overview_bank_data.csv')
df['name'].unique()


from_=['ABSA BANK LTD ','THE STANDARD BANK OF S A LTD ','FIRSTRAND BANK LIMITED ','NEDBANK LTD ','INVESTEC BANK LTD ',\
      'CITIBANK N.A ','CAPITEC BANK ' , 'AFRICAN BANK LIMITED ','JPMORGAN CHASE BANK             ',\
       'THE HONGKONG AND SHANGHAI BANKING CORPORATION LIMITED - JOHANNESBURG BRANCH ',
       'STANDARD CHARTERED BANK ',\
       'CHINA CONSTRUCTION BANK         CORPORATION - JHB BRANCH ',
       'BANK OF CHINA LTD JHB BRANCH    ',
       'MERCANTILE BANK LTD ', 'GRINDROD BANK LTD ',
       'BNP PARIBAS SOUTH AFRICA BRANCH ', 'AFRICAN BANK LIMITED ',
       'BIDVEST BANK LIMITED ', 'ALBARAKA BANK LTD ',
        'HBZ BANK LTD ',
       'SASFIN BANK LTD ', 'UBANK LIMITED ', 'DEUTSCHE BANK AG ',
       'GROBANK LTD ', 'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
       'DISCOVERY BANK LIMITED ', 'GBS MUTUAL BANK '
       
      ]

to_=['ABSA', 'SBSA', 'FNB','NEDBANK', 'INVESTEC',\
    'CITYBANK','CAPITEC','AfricanB','JPM',\
     'HSBC','CHARTERED','ChinaConstruction',
   'BANK OF CHINA LTD JHB BRANCH    ',
   'MERCANTILE BANK LTD ', 'GRINDROD BANK LTD ',
   'BNP PARIBAS SOUTH AFRICA BRANCH ', 'AFRICAN BANK LIMITED ',
   'BIDVEST BANK LIMITED ', 'ALBARAKA BANK LTD ',
    'HBZ BANK LTD ',
   'SASFIN BANK LTD ', 'UBANK LIMITED ', 'DEUTSCHE BANK AG ',
   'GROBANK LTD ', 'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
   'DISCOVERY BANK LIMITED ', 'GBS MUTUAL BANK '

    ]
 
dictionary = dict(zip(from_, to_))

df['name'] = df['name'].map(dictionary)
old_names = [ 'total_assets', 'leverage', 'name']
new_names = [ 'Total_assets', 'Leverage', 'Name']
df.rename(columns=dict(zip(old_names, new_names)), inplace=True)
df['market_share_assets'] = df['Total_assets'].transform(lambda x: x / x.sum())

# create data
df = df[np.isfinite(df['Total_assets'])]
x = df["Total_assets"].values
y = df["market_share_assets"].values
z = df["Leverage"].values

SBSA = df.loc[df["Name"]== 'SBSA']["Total_assets"] 
ABSA = df.loc[df["Name"]== 'ABSA']["Total_assets"]
NEDBANK = df.loc[df["Name"]== 'NEDBANK']["Total_assets"]
FNB = df.loc[df["Name"]== 'FNB']["Total_assets"]

Investec = df.loc[df["Name"]== 'INVESTEC']["Total_assets"]
 
SBSA_lev = df.loc[df["Name"]== 'SBSA']["Leverage"] 
ABSA_lev = df.loc[df["Name"]== 'ABSA']["Leverage"]
NEDBANK_lev = df.loc[df["Name"]== 'NEDBANK']["Leverage"]
FNB_lev = df.loc[df["Name"]== 'FNB']["Leverage"]
Investec_lev = df.loc[df["Name"]== 'INVESTEC']["Leverage"]

df = df[np.isfinite(df['Total_assets'])]

# Change color with c and alpha. I map the color to the X axis value.
ax2.scatter(x, z, s=y*10000, c=z, cmap="ocean_r", linewidth=2)

#Add titles (main and on axis)
ax2.xlabel("Total assets in ZAR, Feb 2020")
ax2.ylabel("Leverage")
ax2.xlim([-200,1.65*10E11])
ax2.ylim([0,15])

ax2.annotate('A', xy=(SBSA, SBSA_lev), xytext=(SBSA, SBSA_lev), color="white")
ax2.annotate('C', xy=(ABSA, ABSA_lev), xytext=(ABSA, ABSA_lev), color="white")
ax2.annotate('D', xy=(NEDBANK, NEDBANK_lev), xytext=(NEDBANK, NEDBANK_lev), color="white")  #, size=4
ax2.annotate('B', xy=(FNB, FNB_lev), xytext=(FNB, FNB_lev), color="white")
ax2.annotate('E', xy=(Investec, Investec_lev), xytext=(Investec, Investec_lev+1), color="black")
# Out:
# Text(4e+11,15.5385,'E')

# %%
# Make plots side by side with function 

def helper_bubbles_2015(file):
    
    
    
    return  x, y , z

# %% [markdown]
# # Get data dec 2015

# %%
y, m = "2015", "12"


import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
file_list=[]

import os
os.chdir('/Users/admin/git_repos/ba900/')

for filename in os.listdir('./data/output/'):
    if filename.endswith(".pkl") and y  in filename:
        unpickle = './data/output/'+str(filename)
        print(unpickle)
        file_list.append(pd.read_pickle(unpickle))
 
 
MASTER = pd.concat(file_list)
MASTER['time'] = pd.to_datetime(MASTER['time'])
MASTER['Value'] = pd.to_numeric(MASTER['Value'])

import sys
import os
import sys
sys.path.append("..") 
from ba900 import assets_to_weights   

transform=assets_to_weights.tranformer()
t=transform.get_biggest_banks( y, m, MASTER, 29)

top10=t.values.tolist()
MASTER=MASTER[MASTER.InstitutionDescription.isin(top10)]
years =[y]
months = [m]
df=transform.get_overview_timeseries(top10,months,years,MASTER)
 
df.to_csv("{}_{}_overview_bank_data.csv".format(y,m))
# Out:
# ./data/output/df2015.pkl
# ba900/assets_to_weights.py:366: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   a['Value'] = pd.to_numeric(a['Value'])
# THE STANDARD BANK OF S A LTD
# ba900/assets_to_weights.py:290: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   BANK['Value'] = pd.to_numeric(BANK['Value'])
# ba900/assets_to_weights.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

 
# create data
df = df[np.isfinite(df['Total_assets'])]


x = df["Total_assets"].values
y = df["market_share_assets"].values
z = df["Leverage"].values

SBSA = df.loc[df["Name"]== 'SBSA']["Total_assets"] 
ABSA = df.loc[df["Name"]== 'ABSA']["Total_assets"]
NEDBANK = df.loc[df["Name"]== 'NEDBANK']["Total_assets"]
FNB = df.loc[df["Name"]== 'FNB']["Total_assets"]

Investec = df.loc[df["Name"]== 'INVESTEC']["Total_assets"]
 
SBSA_lev = df.loc[df["Name"]== 'SBSA']["Leverage"] 
ABSA_lev = df.loc[df["Name"]== 'ABSA']["Leverage"]
NEDBANK_lev = df.loc[df["Name"]== 'NEDBANK']["Leverage"]
FNB_lev = df.loc[df["Name"]== 'FNB']["Leverage"]
Investec_lev = df.loc[df["Name"]== 'INVESTEC']["Leverage"]

df = df[np.isfinite(df['Total_assets'])]

# Change color with c and alpha. I map the color to the X axis value.
plt.scatter(x, z, s=y*10000, c=z, cmap="ocean_r", linewidth=2)

#ns.distplot(x)
#sns.jointplot(x=x, y=z, kind="kde", space=0, color="blue", data=df)
#sns.jointplot(x=y, y=x, data=df,  marginal_kws=dict(bins=15, rug=True),annot_kws=dict(stat="r"),s=40, edgecolor="w", linewidth=1)
 
#
#Add titles (main and on axis)
plt.xlabel("Total assets in ZAR, Dec 2018")
plt.ylabel("Leverage")
plt.xlim([-200,1.55*10E11])
plt.ylim([0,15])

plt.annotate('A', xy=(SBSA, SBSA_lev), xytext=(SBSA, SBSA_lev), color="white")
plt.annotate('C', xy=(ABSA, ABSA_lev), xytext=(0.88061*10E11, ABSA_lev), color="white")
plt.annotate('D', xy=(NEDBANK, NEDBANK_lev), xytext=(0.75061*10E11, NEDBANK_lev), color="white", size=6)
plt.annotate('B', xy=(FNB, FNB_lev), xytext=(0.96*10E11, FNB_lev), color="white")
plt.annotate('E', xy=(Investec, Investec_lev), xytext=(0.4*10E11, Investec_lev+1), color="black")


#plt.title("Assets per bank")
# Out:
# Text(4e+11,12.7562,'Investec')

# %% [markdown]
# #  Dec 2015

# %%
import numpy as np
import pandas as pd
import csv
from matplotlib import cm
import sys
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from mpl_toolkits.mplot3d import Axes3D
import numpy
from numpy.random import randn
from scipy import array, newaxis
import seaborn as sns
from matplotlib.patches import Rectangle
from scipy.interpolate import InterpolatedUnivariateSpline

# %%
#df = pd.read_excel('/Users/Tina/Dropbox/phd/projects/banking_spillovers_contagion/python_plotting/for_fs_deposits.xlsx')
df = pd.read_excel('for_fs_deposits.xlsx')


df = df.loc[~(df==0.00).all(axis=1)]
df = df.round(2)


name = df["Name"].values
phi = df["Total_assets"].values

size_unsecured = df["unsecured_absolute"].values
y2 = df["unsecured_corporate"].values
y3 = df["unsecured_total"].values

y = df["unsecured_hh"].values
x1 = df["fund_manager_share"].values
x2 = df["mmf_deposits_share"].values
x3 = df["insurers_deposits_share"].values
foreign = df["foreign_deposits_share"].values

b= df["hh_deposits_share"].values
c = df["corporate_deposits_non_financial_share"].values

import matplotlib.gridspec as gridspec
fig, (ax1, ax2, ax3) = plt.subplots( nrows=1, ncols=3, sharex=False, sharey=True,  figsize=(10,10))
fig.patch.set_facecolor('xkcd:white')
figure_title = fig.suptitle("Unsecured Lending vs Financial sector deposits", x=0.55 , y=0.95, fontsize=18)

gs = gridspec.GridSpec(2, 4)
gs.update(wspace=0.5)
ax1 = plt.subplot(gs[0, :2], )
ax2 = plt.subplot(gs[0, 2:])
ax3 = plt.subplot(gs[1, 1:3])
#############Data###### ax1
sns.swarmplot(x=x1, y=y3, hue=name, ax=ax1, s=15, palette="RdYlGn",  data=df) 

#############Data######
# Put a legend to the right of the current axis
# ax1.legend_.remove()
ax1.set_xlabel("\n Deposits from Fund Manager\n as a proportion of total assets\n")
ax1.set_ylabel('\n Unsecured lending\n proportion of total assets\n', fontsize=15)  
#axes[0].set_title("Deposits from Fund Manager")
##########
#Annotate datapoints 
# #######
ax1.annotate('AfricanB ', xy=(5.17,0.6 ), xytext=(5.17,0.6), color="black", fontsize=11)
ax1.annotate('Capitec ', xy=(0.3,0.6 ), xytext=(0.3,0.6), color="black", fontsize=11)  
ax1.annotate('SBSA ', xy=(2.7,0.16 ), xytext=(2.7,0.16), color="black", fontsize=11)
ax1.annotate('Investec', xy=(5.4,0.15 ), xytext=(5.4,0.15), color="black", fontsize=11)
ax1.annotate('Nedbank ', xy=(3.2,0.22 ), xytext=(3.2,0.22), color="black", fontsize=11)
ax1.annotate(' ABSA ', xy=(4.21,0.17 ), xytext=(4.21,0.17), color="black", fontsize=11)
ax1.legend_.remove()
#############Data###### ax2
sns.swarmplot(x=x2, y=y3, hue=name, ax=ax2, s=15, palette="RdYlGn",  data=df) 
ax2.set_xlabel("\n Deposits from MMFs\n as a proportion of total assets\n")
ax3.set_ylabel('\n Unsecured lending\n proportion of total assets\n', fontsize=16)  

 
box = ax2.get_position()
ax2.set_position([box.x0, box.y0, box.width , box.height])
ax2.legend(loc='upper left', bbox_to_anchor=(1.1, 0.99)) 


ax2.annotate('AfricanB ', xy=(2.1,0.6 ), xytext=(2.1,0.6), color="black", fontsize=11)
ax2.annotate('FNB ', xy=(2.1,0.18), xytext=(2.1,0.18), color="black", fontsize=11)
ax2.annotate('Capitec ', xy=(0.01,0.6 ), xytext=(0.01,0.6), color="black", fontsize=11)
ax2.annotate('Nedbank ', xy=(0.89,0.22), xytext=(0.89,0.22), color="black", fontsize=11)
ax2.annotate('Grindrod ', xy=(1.1,0.12), xytext=(1.1,0.12), color="black", fontsize=11)
ax2.annotate('SBSA ', xy=(0.008,0.17 ), xytext=(0.008,0.17), color="black", fontsize=11)
#############Data###### ax3
sns.swarmplot(x=x3, y=y3, hue=name, ax=ax3, s=15, palette="RdYlGn",  data=df) 
 
#############ax######
ax3.set_xlabel("\n Deposits from Insurers\n & Pension Funds\n as a proportion of total assets\n")
ax3.annotate('Capitec ', xy=(0.2,0.6 ), xytext=(0.2,0.6), color="black", fontsize=11)
ax3.annotate('AfricanB ', xy=(2.1,0.6 ), xytext=(2.1,0.6), color="black", fontsize=11)
ax3.annotate('SBSA ', xy=(0.41, 0.17 ), xytext=(0.41,0.17), color="black", fontsize=11)
ax3.annotate('FNB ', xy=(1.9,0.21 ), xytext=(1.9,0.21), color="black", fontsize=11)
ax3.annotate('Nedbank ', xy=(2.8,0.21 ), xytext=(2.8,0.21), color="black", fontsize=11)
ax3.annotate('ABSA ', xy=(3.2,0.16 ), xytext=(3.2,0.16), color="black", fontsize=11)
ax3.annotate('Sasfin', xy=(3.9,0.11), xytext=(3.9,0.11), color="black", fontsize=11)
ax3.legend_.remove()


plt.subplots_adjust(left=0.125, bottom=0.2, right=0.9, top=None, wspace=0.2, hspace=0.5) 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

 
df = pd.read_excel('SA_balance_sheets_Dec15.xlsx')
 
# create data
df = df[np.isfinite(df['Total_assets'])]


x = df["Total_assets"].values
y = df["market_share_assets"].values
z = df["Leverage"].values

SBSA = df.loc[df["Name"]== 'SBSA']["Total_assets"] 
ABSA = df.loc[df["Name"]== 'ABSA']["Total_assets"]
NEDBANK = df.loc[df["Name"]== 'NEDBANK']["Total_assets"]
FNB = df.loc[df["Name"]== 'FNB']["Total_assets"]

Investec = df.loc[df["Name"]== 'INVESTEC']["Total_assets"]
 
SBSA_lev = df.loc[df["Name"]== 'SBSA']["Leverage"] 
ABSA_lev = df.loc[df["Name"]== 'ABSA']["Leverage"]
NEDBANK_lev = df.loc[df["Name"]== 'NEDBANK']["Leverage"]
FNB_lev = df.loc[df["Name"]== 'FNB']["Leverage"]
Investec_lev = df.loc[df["Name"]== 'INVESTEC']["Leverage"]

df = df[np.isfinite(df['Total_assets'])]

# Change color with c and alpha. I map the color to the X axis value.
plt.scatter(x, z, s=y*10000, c=z, cmap="ocean_r", linewidth=2)

#ns.distplot(x)
#sns.jointplot(x=x, y=z, kind="kde", space=0, color="blue", data=df)
#sns.jointplot(x=y, y=x, data=df,  marginal_kws=dict(bins=15, rug=True),annot_kws=dict(stat="r"),s=40, edgecolor="w", linewidth=1)
 
#
#Add titles (main and on axis)
plt.xlabel("Total assets in ZAR, Dec 2015")
plt.ylabel("Leverage")
plt.xlim([-200,1.35*10E11])

plt.annotate('SBSA', xy=(SBSA, SBSA_lev), xytext=(1.18*10E11, SBSA_lev), color="white")
plt.annotate('ABSA', xy=(ABSA, ABSA_lev), xytext=(0.88061*10E11, ABSA_lev), color="white")
plt.annotate('NEDBANK', xy=(NEDBANK, NEDBANK_lev), xytext=(0.75061*10E11, NEDBANK_lev), color="white", size=6)
plt.annotate('FNB', xy=(FNB, FNB_lev), xytext=(0.96*10E11, FNB_lev), color="white")
plt.annotate('Investec', xy=(Investec, Investec_lev), xytext=(0.4*10E11, Investec_lev+1), color="black")


#plt.title("Assets per bank")
# Out:
# Text(4e+11,15.5385,'Investec')
# /anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
###############
###############
##### 2025!!! #####
####################
df = pd.read_csv('/Users/admin/git_repos/ba900/data/bubbles/2015_12_overview_bank_data.csv')
df['name'].unique()
from_=['ABSA BANK LTD ',
       'THE STANDARD BANK OF S A LTD ',
       'FIRSTRAND BANK LIMITED ',
       'NEDBANK LTD ',
       'INVESTEC BANK LTD ',\
        'CITIBANK N.A ',
       'CAPITEC BANK ' ,
        'AFRICAN BANK LIMITED ',    
       'JPMORGAN CHASE BANK             ',\
        'THE HONGKONG AND SHANGHAI BANKING CORPORATION LIMITED - JOHANNESBURG BRANCH ',
        'STANDARD CHARTERED BANK ', 
       'CHINA CONSTRUCTION BANK         CORPORATION - JHB BRANCH ',
       'BANK OF CHINA LTD JHB BRANCH    ', 
       'GRINDROD BANK LTD ',
       'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
       'MERCANTILE BANK LTD ',
       'DEUTSCHE BANK AG ',
       'ALBARAKA BANK LTD ', 
       'UBANK LIMITED ', 
       'HBZ BANK LTD ',
       'SASFIN BANK LTD ',
       'BNP PARIBAS SA ', 
       'BIDVEST BANK LIMITED ',
       'BANK OF BARODA ', 
       'STATE BANK OF INDIA ',
       'THE S A BANK OF ATHENS LTD '
      ]
to_=['ABSA', 
     'SBSA', 
     'FNB',
     'NEDBANK', 
     'INVESTEC',\
    'CITYBANK',
     'CAPITEC',
     'AfricanB',
     'JPM',\
     'HSBC',
     'CHARTERED','ChinaConstruction',
     'BANKofCHINA', 
    'GRINDROD BANK LTD ',
       'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
       'MERCANTILE BANK LTD ',
       'DEUTSCHE BANK AG ',
       'ALBARAKA BANK LTD ', 
       'UBANK LIMITED ', 
       'HBZ BANK LTD ',
       'SASFIN BANK LTD ',
       'BNP PARIBAS SA ', 
       'BIDVEST BANK LIMITED ',
       'BANK OF BARODA ', 
       'STATE BANK OF INDIA ',
       'THE S A BANK OF ATHENS LTD '   
    ]
 
dictionary = dict(zip(from_, to_))
df['name'] = df['name'].map(dictionary)
old_names = [ 'total_assets', 'leverage', 'name']
new_names = [ 'Total_assets', 'Leverage', 'Name']
df.rename(columns=dict(zip(old_names, new_names)), inplace=True)
df['market_share_assets'] = df['Total_assets'].transform(lambda x: x / x.sum())

# create data
df = df[np.isfinite(df['Total_assets'])]
x = df["Total_assets"].values
y = df["market_share_assets"].values
z = df["Leverage"].values

SBSA = df.loc[df["Name"]== 'SBSA']["Total_assets"] 
ABSA = df.loc[df["Name"]== 'ABSA']["Total_assets"]
NEDBANK = df.loc[df["Name"]== 'NEDBANK']["Total_assets"]
FNB = df.loc[df["Name"]== 'FNB']["Total_assets"]
Investec = df.loc[df["Name"]== 'INVESTEC']["Total_assets"]
SBSA_lev = df.loc[df["Name"]== 'SBSA']["Leverage"] 
ABSA_lev = df.loc[df["Name"]== 'ABSA']["Leverage"]
NEDBANK_lev = df.loc[df["Name"]== 'NEDBANK']["Leverage"]
FNB_lev = df.loc[df["Name"]== 'FNB']["Leverage"]
Investec_lev = df.loc[df["Name"]== 'INVESTEC']["Leverage"]

df = df[np.isfinite(df['Total_assets'])]


fig, (ax1, ax2) = plt.subplots(1, 2,    figsize=(10,4))
fig.suptitle('Leverage vs bank size, 2015 and 2020 \n')


# Change color with c and alpha. I map the color to the X axis value.
ax1.scatter(x, z, s=y*10000, c=z, cmap="ocean_r", linewidth=2)
#Add titles (main and on axis)
ax1.set_xlabel("Total assets in ZAR, Dec 2015")
ax1.set_ylabel("Leverage")
ax1.set_xlim([-200,1.35*10E11])
ax1.annotate('A', xy=(SBSA, SBSA_lev), xytext=(1.18*10E11, SBSA_lev), color="white")
ax1.annotate('C', xy=(ABSA, ABSA_lev), xytext=(0.88061*10E11, ABSA_lev), color="white")
ax1.annotate('D', xy=(NEDBANK, NEDBANK_lev), xytext=(0.75061*10E11, NEDBANK_lev), color="white") # size=6
ax1.annotate('B', xy=(FNB, FNB_lev), xytext=(0.96*10E11, FNB_lev), color="white")
ax1.annotate('E', xy=(Investec, Investec_lev), xytext=(0.4*10E11, Investec_lev+2), color="black")

###############
###############
##### 2020!!! #####
####################
df = pd.read_csv('/Users/admin/git_repos/ba900/data/bubbles/2020_02_overview_bank_data.csv')
df['name'].unique()

from_=['ABSA BANK LTD ','THE STANDARD BANK OF S A LTD ','FIRSTRAND BANK LIMITED ','NEDBANK LTD ','INVESTEC BANK LTD ',\
      'CITIBANK N.A ','CAPITEC BANK ' , 'AFRICAN BANK LIMITED ','JPMORGAN CHASE BANK             ',\
       'THE HONGKONG AND SHANGHAI BANKING CORPORATION LIMITED - JOHANNESBURG BRANCH ',
       'STANDARD CHARTERED BANK ',\
       'CHINA CONSTRUCTION BANK         CORPORATION - JHB BRANCH ',
       'BANK OF CHINA LTD JHB BRANCH    ',
       'MERCANTILE BANK LTD ', 'GRINDROD BANK LTD ',
       'BNP PARIBAS SOUTH AFRICA BRANCH ', 'AFRICAN BANK LIMITED ',
       'BIDVEST BANK LIMITED ', 'ALBARAKA BANK LTD ',
        'HBZ BANK LTD ',
       'SASFIN BANK LTD ', 'UBANK LIMITED ', 'DEUTSCHE BANK AG ',
       'GROBANK LTD ', 'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
       'DISCOVERY BANK LIMITED ', 'GBS MUTUAL BANK '
      ]
to_=['ABSA', 'SBSA', 'FNB','NEDBANK', 'INVESTEC',\
    'CITYBANK','CAPITEC','AfricanB','JPM',\
     'HSBC','CHARTERED','ChinaConstruction',
   'BANK OF CHINA LTD JHB BRANCH    ',
   'MERCANTILE BANK LTD ', 'GRINDROD BANK LTD ',
   'BNP PARIBAS SOUTH AFRICA BRANCH ', 'AFRICAN BANK LIMITED ',
   'BIDVEST BANK LIMITED ', 'ALBARAKA BANK LTD ',
    'HBZ BANK LTD ',
   'SASFIN BANK LTD ', 'UBANK LIMITED ', 'DEUTSCHE BANK AG ',
   'GROBANK LTD ', 'SOCIETE GENERALE JOHANNESBURG   BRANCH ',
   'DISCOVERY BANK LIMITED ', 'GBS MUTUAL BANK '
    ]
 
dictionary = dict(zip(from_, to_))

df['name'] = df['name'].map(dictionary)
old_names = [ 'total_assets', 'leverage', 'name']
new_names = [ 'Total_assets', 'Leverage', 'Name']
df.rename(columns=dict(zip(old_names, new_names)), inplace=True)
df['market_share_assets'] = df['Total_assets'].transform(lambda x: x / x.sum())

# create data
df = df[np.isfinite(df['Total_assets'])]
x = df["Total_assets"].values
y = df["market_share_assets"].values
z = df["Leverage"].values

SBSA = df.loc[df["Name"]== 'SBSA']["Total_assets"] 
ABSA = df.loc[df["Name"]== 'ABSA']["Total_assets"]
NEDBANK = df.loc[df["Name"]== 'NEDBANK']["Total_assets"]
FNB = df.loc[df["Name"]== 'FNB']["Total_assets"]

Investec = df.loc[df["Name"]== 'INVESTEC']["Total_assets"]
 
SBSA_lev = df.loc[df["Name"]== 'SBSA']["Leverage"] 
ABSA_lev = df.loc[df["Name"]== 'ABSA']["Leverage"]
NEDBANK_lev = df.loc[df["Name"]== 'NEDBANK']["Leverage"]
FNB_lev = df.loc[df["Name"]== 'FNB']["Leverage"]
Investec_lev = df.loc[df["Name"]== 'INVESTEC']["Leverage"]

df = df[np.isfinite(df['Total_assets'])]

# Change color with c and alpha. I map the color to the X axis value.
ax2.scatter(x, z, s=y*10000, c=z, cmap="ocean_r", linewidth=2)

#Add titles (main and on axis)
ax2.set_xlabel("Total assets in ZAR, Feb 2020")
ax2.set_ylabel("Leverage")
ax2.set_xlim([-200,1.65*10E11])
ax2.set_ylim([0,22.5])

ax2.annotate('A', xy=(SBSA, SBSA_lev), xytext=(SBSA, SBSA_lev), color="white")
ax2.annotate('C', xy=(ABSA, ABSA_lev), xytext=(ABSA, ABSA_lev-2), color="white")
ax2.annotate('D', xy=(NEDBANK, NEDBANK_lev), xytext=(NEDBANK, NEDBANK_lev), color="white")  #, size=4
ax2.annotate('B', xy=(FNB, FNB_lev), xytext=(FNB, FNB_lev), color="white")
ax2.annotate('E', xy=(Investec, Investec_lev), xytext=(Investec, Investec_lev+2), color="black")


fig.savefig('bubbles_2015_2020.png', bbox_inches='tight')
